# %%
# %load_ext autoreload
# %autoreload 2

# %%
import yolov5
import yolov5.train
from ivlib.ivlib.utils import margins_begone, fdir
margins_begone()
# Out:
#     <style>
#          #notebook { padding-top:0px !important; }
#          .container { width:100% !important; }
#          .end_space { min-height:0px !important; }
#          div.prompt { min-width:0px; }
#          .prompt { min-width:0px; }
#          .output_area { background-color:#eeeeee;}
#       </style>

# %%
yolov5.train.run(data="visionUI/vui_datasets/dataset.yaml", 
                 cfg="yolov5s.yaml", 
                 weights="", 
                 batch_size=8, epochs=1000, patience=50)
# Out:
# train: weights=, cfg=yolov5s.yaml, data=visionUI/vui_datasets/dataset.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=1000, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=50, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# {'data': 'visionUI/vui_datasets/dataset.yaml', 'cfg': 'yolov5s.yaml', 'weights': '', 'batch_size': 8, 'epochs': 1000, 'patience': 50}
# github: ⚠️ YOLOv5 is out of date by 9 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.2-197-g375ac36 Python-3.8.10 torch-1.7.1 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4042MiB)
#
# ...

# %%
yolov5.train.run(data="visionUI/vui_datasets/dataset.yaml", 
                 cfg="yolov5s.yaml", 
                 resume="yolov5/runs/train/exp13/weights/best.pt", 
                 batch_size=8, epochs=5000, patience=500)
# Out:
# train: weights=yolov5/yolov5s.pt, cfg=yolov5s.yaml, data=visionUI/vui_datasets/dataset.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=5000, batch_size=8, imgsz=640, rect=False, resume=yolov5/runs/train/exp13/weights/best.pt, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=500, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# {'data': 'visionUI/vui_datasets/dataset.yaml', 'cfg': 'yolov5s.yaml', 'resume': 'yolov5/runs/train/exp13/weights/best.pt', 'batch_size': 8, 'epochs': 5000, 'patience': 500}
# From https://github.com/ultralytics/yolov5
#    eef9057..8236d88  master         -> origin/master
# ...
